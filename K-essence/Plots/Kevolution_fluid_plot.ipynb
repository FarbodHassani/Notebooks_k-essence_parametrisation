# %% [markdown]
# # Notebook for comparison beween  Gevolution and realized class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
ColorsI = ["red","blue","green","purple","darkcyan","gold","maroon","black","darkslategrey",
           "darkgreen","navy","indigo","magenta","salmon","dodgerblue","springgreen","plum",
           "cyan","khaki","lightcoral","gray"]

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %%
addressGev="./../CSCS_Results/kessence_cs2e6_w09/output/";
address_fld="./../CSCS_Results/fluid_gevolution_deltakess/";
add_LCDM = "./../CSCS_Results/GR_LCDM/output/"
Gev_deltam_zall=[]
Gev_deltakess_zall=[]
Gev_phi_kess_zall=[]

Gev_fld_phi_zall=[]
Gev_fld_deltam_zall=[]
Gev_fld_deltkess_zall=[]

Gev_lcdm_phi_zall=[]
Gev_lcdm_deltam_zall=[]
z_list=[ 100,50,30,10,6,5,4,3,2,1,0]
z_list_fld=[100,50, 10, 6, 1, 0]
maxNum=np.shape(z_list)[0]
maxNum_fld=np.shape(z_list_fld)[0]

for i in range (0,maxNum_fld):
    Gev_lcdm_phi_zall.append(np.loadtxt("./"+add_LCDM+"LCDM_pk"+str(i).zfill(3)+"_phi.dat"))
    Gev_lcdm_deltam_zall.append(np.loadtxt("./"+add_LCDM+"LCDM_pk"+str(i).zfill(3)+"_delta.dat"))
#     Gev_fld_deltkess_zall.append(np.loadtxt("./"+address_fld+"kess_pk_cs_e3_"+str(i).zfill(3)+"_deltaclass.dat"))


for i in range (0,maxNum_fld):
    Gev_fld_phi_zall.append(np.loadtxt("./"+address_fld+"kess_pk_cs_e3_"+str(i).zfill(3)+"_phi.dat"))
    Gev_fld_deltam_zall.append(np.loadtxt("./"+address_fld+"kess_pk_cs_e3_"+str(i).zfill(3)+"_delta.dat"))
    Gev_fld_deltkess_zall.append(np.loadtxt("./"+address_fld+"kess_pk_cs_e3_"+str(i).zfill(3)+"_deltaclass.dat"))

for i in range (0,maxNum):
    Gev_phi_kess_zall.append(np.loadtxt("./"+addressGev+"kess_pk_cs_e3_"+str(i).zfill(3)+"_phi.dat"))
    Gev_deltam_zall.append(np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_"+str(i).zfill(3)+"_delta.dat"))
    Gev_deltakess_zall.append(np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_"+str(i).zfill(3)+"_delta_kess.dat"))

# %% [markdown]
# # Matter power fluid-class vs Gevolution

# %%
plt.figure(figsize=(18,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)

i=9
plt.loglog(Gev_deltam_zall[i][:,0], Gev_deltam_zall[i][:,1],color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=4
plt.loglog(Gev_fld_deltam_zall[i][:,0], Gev_fld_deltam_zall[i][:,1],color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

i=10
plt.loglog(Gev_deltam_zall[i][:,0], Gev_deltam_zall[i][:,1],color=ColorsI[i],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
# #     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=5
plt.loglog(Gev_fld_deltam_zall[i][:,0], Gev_fld_deltam_zall[i][:,1],color=ColorsI[i+1],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))


plt.axvspan(7.52, 14, alpha=0.5, color='pink')

plt.legend(bbox_to_anchor=(0.1, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P}_{\delta m}(k,z)$",fontsize=18)
plt.xlim(0.01,20)
# plt.ylim(2.e-5,100)
plt.grid(True)
plt.show()

# %% [markdown]
# # Phi power realized-Class vs Gevolution

# %%
plt.figure(figsize=(18,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)

i=0
plt.loglog(Gev_phi_kess_zall[i][:,0], Gev_phi_kess_zall[i][:,1],color=ColorsI[i],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=0
plt.loglog(Gev_fld_phi_zall[i][:,0], Gev_fld_phi_zall[i][:,1],color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

i=10
plt.loglog(Gev_phi_kess_zall[i][:,0], Gev_phi_kess_zall[i][:,1],color=ColorsI[i],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
# #     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=5
plt.loglog(Gev_fld_phi_zall[i][:,0], Gev_fld_phi_zall[i][:,1],color=ColorsI[i+1],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))


plt.axvspan(7.52, 14, alpha=0.5, color='pink')

plt.legend(bbox_to_anchor=(0.01, 0.40, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P}_{\Phi}(k,z)$",fontsize=18)
plt.xlim(0.01,3.2)
# plt.ylim(2.e-5,100)
plt.grid(True)
plt.show()

# %% [markdown]
# # delta_kess power Fluid vs k-evolution

# %%
plt.figure(figsize=(18,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)

i=9
plt.loglog(Gev_deltakess_zall[i][:,0], Gev_deltakess_zall[i][:,1],color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=4
plt.loglog(Gev_fld_deltkess_zall[i][:,0], Gev_fld_deltkess_zall[i][:,1],color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

i=1
plt.loglog(Gev_deltakess_zall[i][:,0], Gev_deltakess_zall[i][:,1],color=ColorsI[i],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
# #     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=1
plt.loglog(Gev_fld_deltkess_zall[i][:,0], Gev_fld_deltkess_zall[i][:,1],color=ColorsI[i+1],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))


plt.axvspan(7.52, 14, alpha=0.5, color='pink')

plt.legend(bbox_to_anchor=(0.01, 0.10, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P}_{\delta kess}(k,z)$",fontsize=18)
plt.xlim(0.01,3.2)
plt.ylim(2.e-12,1.e-3)
plt.grid(True)
plt.show()

# %% [markdown]
# # |mu(k,z)|, K-evolution vs realized-class

# %%
def Hubble_conf_Mpc(a):
    w=-0.9;h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
w=-0.9;h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=Omega_b+Omega_cdm;
plt.figure(figsize=(18,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)
#  \mu(z,k) = 2 k^2 / (3 H_0^2\Omega_{m,0}(1+z)^3) P_\phi(k,z) / P_\delta(k,z).
i=10
coeff_field = 2./(3. * Hubble_conf_Mpc(1./(1.+0))**2 *Omega_m * (1+z_list[i])**3 )

# plt.loglog(Gev_deltam_zall[i][:,0], Gev_deltam_zall[i][:,0]**2 * np.sqrt(Gev_phi_kess_zall[i][:,1]/Gev_deltam_zall[i][:,1] ) * coeff_field,color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=5
coeff_fld = 2./(3. * Hubble_conf_Mpc(1./(1.+0))**2 *Omega_m * (1+z_list_fld[i])**3 )

plt.loglog(Gev_fld_deltam_zall[i][:,0],Gev_fld_deltam_zall[i][:,0]**2 * np.sqrt(Gev_fld_phi_zall[i][:,1]/Gev_fld_deltam_zall[i][:,1] ) * coeff_fld,color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))
plt.loglog(Gev_lcdm_deltam_zall[i][:,0],Gev_lcdm_deltam_zall[i][:,0]**2 * np.sqrt(Gev_lcdm_phi_zall[i][:,1]/Gev_lcdm_deltam_zall[i][:,1] ) * coeff_fld,color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"lcdm, z="+str(z_list_fld[i]))

# i=9
# coeff_field = 2./(3. * Hubble_conf_Mpc(1./(1.+z_list[i]))**2 *Omega_m * (1+z_list[i])**3 )

# plt.loglog(Gev_deltam_zall[i][:,0], Gev_deltam_zall[i][:,0]**2 * np.sqrt(Gev_phi_kess_zall[i][:,1]/Gev_deltam_zall[i][:,1] ) * coeff_field,color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
# #     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
# i=4
# coeff_fld = 2./(3. * Hubble_conf_Mpc(1./(1.+z_list_fld[i]))**2 *Omega_m * (1+z_list_fld[i])**3 )

# plt.loglog(Gev_fld_deltam_zall[i][:,0],Gev_fld_deltam_zall[i][:,0]**2 * np.sqrt(Gev_fld_phi_zall[i][:,1]/Gev_fld_deltam_zall[i][:,1] ) * coeff_fld,color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

# i=0
# coeff_field = 2./(3. * Hubble_conf_Mpc(1./(1.+0))**2 *Omega_m * (1+z_list[i])**3 )

# plt.loglog(Gev_deltam_zall[i][:,0], Gev_deltam_zall[i][:,0]**2 * np.sqrt(Gev_phi_kess_zall[i][:,1]/Gev_deltam_zall[i][:,1] ) * coeff_field,color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
# #     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
# i=0
# coeff_fld = 2./(3. * Hubble_conf_Mpc(1./(1.+0))**2 *Omega_m * (1+z_list_fld[i])**3 )

# plt.loglog(Gev_fld_deltam_zall[i][:,0],Gev_fld_deltam_zall[i][:,0]**2 * np.sqrt(Gev_fld_phi_zall[i][:,1]/Gev_fld_deltam_zall[i][:,1] ) * coeff_fld,color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

plt.axvspan(7.52, 14, alpha=0.5, color='pink')

plt.legend(bbox_to_anchor=(0.0, 0.10, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mu(k,z) $",fontsize=18)
plt.xlim(0.03,2)
# plt.ylim(2.,2.3)
plt.grid(True)
plt.show()

# %% [markdown]
# # kevolution mu interpolation on fld k

# %%
mu_kev_z_all=[]
mu_kev=[]
for i in range(0,1):
    mu_kev=np.sqrt(Gev_deltam_zall[i][:,1]/Gev_phi_kess_zall[i][:,1] )
    np.shape(mu_kev)
    interp_fld_mu=interp1d(Gev_phi_kess_zall[i][:,0],mu_kev[:]) 
#     mu_kev_z_all.append(interp_fld_mu(Gev_fld_phi_zall[i][:100,0] ) )
np.shape(mu_kev)
np.shape(Gev_fld_phi_zall)
np.shape(mu_kev)

# np.shape(mu_kev_z_all)
# Out:
# (1024,)

# %% [markdown]
# # The error on mu from class

# %%
plt.figure(figsize=(18,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)

i=9
plt.loglog(Gev_deltam_zall[i][:,0], np.sqrt(Gev_deltam_zall[i][:,1]/Gev_phi_kess_zall[i][:,1] ),color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=4
plt.loglog(Gev_fld_deltam_zall[i][:,0],  np.sqrt(Gev_fld_deltam_zall[i][:,1]/Gev_fld_phi_zall[i][:,1] ),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))
i=10
plt.loglog(Gev_deltam_zall[i][:,0], np.sqrt(Gev_deltam_zall[i][:,1]/Gev_phi_kess_zall[i][:,1] ),color=ColorsI[i-3],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=5
plt.loglog(Gev_fld_deltam_zall[i][:,0],  np.sqrt(Gev_fld_deltam_zall[i][:,1]/Gev_fld_phi_zall[i][:,1] ),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))

i=0
plt.loglog(Gev_deltam_zall[i][:,0], np.sqrt(Gev_deltam_zall[i][:,1]/Gev_phi_kess_zall[i][:,1] ),color=ColorsI[i+1],linestyle='solid',lw=2.5,  label=r"k-evolution, z="+str(z_list[i]))
#     plt.loglog(class_phi_kess_zall[i][:,0], class_phi_kess_zall[i][:,0]**3 * class_delta_kess_zall[i][:,1]/(2. * np.pi**2),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"class, z="+str(z_list[i]))
i=0
plt.loglog(Gev_fld_deltam_zall[i][:,0],  np.sqrt(Gev_fld_deltam_zall[i][:,1]/Gev_fld_phi_zall[i][:,1] ),color=ColorsI[i],linestyle='dashed',lw=2.5,  label=r"Realized class, z="+str(z_list_fld[i]))


plt.axvspan(7.52, 14, alpha=0.5, color='pink')

plt.legend(bbox_to_anchor=(0.1, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mu(k,z)$",fontsize=18)
plt.xlim(0.01,3.2)
# plt.ylim(2.e-5,100)
plt.grid(True)
plt.show()
